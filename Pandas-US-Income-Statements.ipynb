# %%
import pandas as pd
income_data = pd.read_csv('/Users/semani/Documents/Code/AIInvestor/Data/us-income-annual.csv', delimiter=";")
income_data
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0          A     45846      USD         2016            FY  2016-10-31
# 1          A     45846      USD         2017            FY  2017-10-31
# 2          A     45846      USD         2018            FY  2018-10-31
# 3          A     45846      USD         2019            FY  2019-10-31
# 4          A     45846      USD         2020            FY  2020-10-31
# ...      ...       ...      ...          ...           ...         ...
# 10617   ZYXI    171401      USD         2015            FY  2015-12-31
# 10618   ZYXI    171401      USD         2016            FY  2016-12-31
# 10619   ZYXI    171401      USD         2017            FY  2017-12-31
# 10620   ZYXI    171401      USD         2018            FY  2018-12-31
# 10621   ZYXI    171401      USD         2019            FY  2019-12-31
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# ...

# %%
print(income_data.keys())
# Out:
# Index(['Ticker', 'SimFinId', 'Currency', 'Fiscal Year', 'Fiscal Period',
#        'Report Date', 'Publish Date', 'Restated Date', 'Shares (Basic)',
#        'Shares (Diluted)', 'Revenue', 'Cost of Revenue', 'Gross Profit',
#        'Operating Expenses', 'Selling, General & Administrative',
#        'Research & Development', 'Depreciation & Amortization',
#        'Operating Income (Loss)', 'Non-Operating Income (Loss)',
#        'Interest Expense, Net', 'Pretax Income (Loss), Adj.',
#        'Abnormal Gains (Losses)', 'Pretax Income (Loss)',
#        'Income Tax (Expense) Benefit, Net',
#        'Income (Loss) from Continuing Operations',
#        'Net Extraordinary Gains (Losses)', 'Net Income',
#        'Net Income (Common)'],
#       dtype='object')

# %%
ticker_set = set(income_data['Ticker'].values)

# %%
print(ticker_set)
# Out:
# {'UPST', 'DVA', 'AKS', 'STJ', 'SHO', 'WPC', 'ADOM', 'ALRN', 'CBI', 'CRM', 'EPM', 'CR', 'Y', 'PRO', 'FLIR', 'ADFK', 'JBHT', 'FMC', 'RTX', 'WYNN', 'LEAF', 'DSKE', 'MGEE', 'ATUS', 'BRC', 'CTAS', 'CK00015503', 'ESTA', 'OSK', 'NTUS', 'MYO', 'TM-28', 'DXCM', 'CCXI', 'CRVS', 'KRA', 'HWM', 'CNXC', 'ADES', 'FIVN', 'FLEX', 'TAST', 'SNX', 'LII', 'MCD', 'EFX', 'CALD', 'VERI', 'RHT', 'CASA', 'CSWI', 'HLIO', 'CMRO', 'SMSI', 'GBX', 'ECYT', 'FSLY', 'OPEN', 'LPTH', 'IEP', 'MGNI', 'LH', 'VZ', 'CCK', 'BA', 'NNDM', 'ROL', 'LOGI', 'ROP', 'TAYD', 'HL', 'AMWD', 'RHE', 'BC', 'AKR', 'CMBM', 'BRMK', 'MDXG', 'TPIC', 'CSGP', 'BLOX', 'ZTS', 'CSTL', 'ARCH', 'SURF', 'SWBI', 'OHI', 'SNCE', 'JAZZ', 'WTRH', 'CMCO', 'PKI', 'IO', 'FL', 'EFOI', 'ETR', 'JBL', 'KND', 'SNA', 'ENS', 'FBHS', 'LPX', 'YGYI', 'SIGM', 'NRG', 'LLL', 'SAVE', 'HSII', 'LXU', 'NTRI', 'HCOM', 'AMKR', 'SNAK', 'BIG', 'QTNA', 'EVH', 'EGAN', 'CRIS', 'HBI', 'AVLR', 'CE', 'DLX', 'NET', 'MRO', 'ADUS', 'NVR', 'ADPT', 'DDOG', 'APPS', 'SYRS', 'ADM', 'TPB', 'PBY
# ...

# %%
IsIt2017 = (income_data['Fiscal Year'] == 2017)

# %%
income_data[IsIt2017]
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 1          A     45846      USD         2017            FY  2017-10-31
# 7         AA    367153      USD         2017            FY  2017-12-31
# 13       AAL     68568      USD         2017            FY  2017-12-31
# 18      AAMC    847094      USD         2017            FY  2017-12-31
# 23       AAN    441241      USD         2017            FY  2017-12-31
# ...      ...       ...      ...          ...           ...         ...
# 10601   ZUMZ     45730      USD         2017            FY  2018-01-31
# 10604    ZUO    994625      USD         2017            FY  2018-01-31
# 10609    ZVO    901866      USD         2017            FY  2017-12-31
# 10614   ZYNE    901704      USD         2017            FY  2017-12-31
# 10619   ZYXI    171401      USD         2017            FY  2017-12-31
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# ...

# %%
income_data['Net Income'].hist()
# Out:
# <AxesSubplot:>

# %%
# Histogram for fiscal year 2019 by net income
IsIt2019 = (income_data['Fiscal Year'] == 2019)
from matplotlib import pyplot as plt # importing plotting library
income_data[IsIt2019]['Net Income'].hist(bins=100, log=True)
plt.title('USA Corporate Net Income for 2019')
plt.xlabel('Value in USD')
plt.ylabel('Number of Instances')
print('Max value is: ', income_data[IsIt2019]['Net Income'].max())
# Out:
# Max value is:  81417000000

# %%
income_data_2019 = income_data[IsIt2019]
income_data_2019
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 3          A     45846      USD         2019            FY  2019-10-31
# 9         AA    367153      USD         2019            FY  2019-12-31
# 15       AAL     68568      USD         2019            FY  2019-12-31
# 20      AAMC    847094      USD         2019            FY  2019-12-31
# 25       AAN    441241      USD         2019            FY  2019-12-31
# ...      ...       ...      ...          ...           ...         ...
# 10603   ZUMZ     45730      USD         2019            FY  2020-01-31
# 10606    ZUO    994625      USD         2019            FY  2020-01-31
# 10611    ZVO    901866      USD         2019            FY  2019-12-31
# 10616   ZYNE    901704      USD         2019            FY  2019-12-31
# 10621   ZYXI    171401      USD         2019            FY  2019-12-31
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# ...

# %%
income_data_2019.sort_values(by=['Net Income'], ascending=False)
# Out:
#      Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 1464  BRK-A     71306      USD         2019            FY  2019-12-31
# 44     AAPL    111052      USD         2019            FY  2019-09-30
# 6303   MSFT     59265      USD         2019            FY  2019-06-30
# 4147   GOOG        18      USD         2019            FY  2019-12-31
# 4824   INTC     85652      USD         2019            FY  2019-12-31
# ...     ...       ...      ...          ...           ...         ...
# 3923  FTRCQ    388949      USD         2019            FY  2019-12-31
# 6677    NOV    378193      USD         2019            FY  2019-12-31
# 7198    PCG    378198      USD         2019            FY  2019-12-31
# 9644   UBER    914943      USD         2019            FY  2019-12-31
# 8511    SLB    353500      USD         2019            FY  2019-12-31
#
#      Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# ...
