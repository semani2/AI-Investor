# %%
import pandas as pd
import pandas_datareader.data as pdr
from matplotlib import pyplot as plt

start = pd.to_datetime('2020-01-01')
end = pd.to_datetime('2021-12-30')

tickerData = pdr.DataReader('SPY', 'yahoo', start, end)

plt.plot(tickerData['Open'])
plt.grid()
plt.xlabel('Date')
plt.ylabel('SPY Values')
plt.title('SPY: Jan 2020 - Dec 2021')
# Out:
# Text(0.5, 1.0, 'SPY: Jan 2020 - Dec 2021')

# %%
#TickerData is a timeseries data with time as the index
tickerData
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-02  324.890015  322.529999  323.540009  324.869995  59151200.0
# 2020-01-03  323.640015  321.100006  321.160004  322.410004  77709700.0
# 2020-01-06  323.730011  320.359985  320.489990  323.640015  55653900.0
# 2020-01-07  323.540009  322.239990  323.019989  322.730011  40496400.0
# 2020-01-08  325.779999  322.670013  322.940002  324.450012  68296000.0
# ...                ...         ...         ...         ...         ...
# 2021-12-23  472.190002  468.640015  468.750000  470.600006  56384300.0
# 2021-12-27  477.309998  472.010010  472.059998  477.260010  56808600.0
# 2021-12-28  478.809998  476.059998  477.720001  476.869995  47274600.0
# 2021-12-29  478.559998  475.920013  476.980011  477.480011  54354300.0
# 2021-12-30  479.000000  477.700012  477.929993  478.230011  24279675.0
#
#              Adj Close
# Date
# 2020-01-02  314.717194
# 2020-01-03  312.334045
# 2020-01-06  313.525665
# ...

# %%
# ILoc Examples

# Last 5 rows
tickerData.iloc[-5]

# FIrst 5 rows
tickerData.iloc[:5]

# Particular row
tickerData.iloc[101]

# Specific date using the loc function
tickerData.loc['2021-05-10']
# Out:
# High         4.227400e+02
# Low          4.178100e+02
# Open         4.225000e+02
# Close        4.179400e+02
# Volume       8.185240e+07
# Adj Close    4.137904e+02
# Name: 2021-05-10 00:00:00, dtype: float64

# %%
tickerData.loc[tickerData.index>'2021-01-02']['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
tickerData.loc[tickerData.index>'2021-01-02']['Volume'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
